# %%
from useful_scit.imps import (pd,np,xr,za,mpl,plt,sns, pjoin, os,glob,dt,
    sys,ucp,log, splot, crt,axsplot)
import flexpart_management.modules.constants as co
import flexpart_management.modules.flx_array as fa

# %%
path = '/homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/'+\
'runs/run_2019-09-25_15-25-01_/*-*-*/flx*.nc'
PATH_OUT = '/homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/'+\
'runs/run_2019-09-25_15-25-01_/check_plots'

# %%
os.mkdir(PATH_OUT)

# %%
ls_files = glob.glob(path)

# %%
ls_files.sort()

# %%
P='PATH'
N='NAME'
D='DOM'
O='OUT'
ND = 'NAME_DAY'
DO = 'DIR_OUT'
df = pd.DataFrame(ls_files,columns=[P])

# %%
df[N]=df[P].apply(lambda p: os.path.basename(p))
df[ND]=df.apply(lambda r: os.path.basename(os.path.dirname(r[P])),axis=1)
df[O]=df.apply(lambda r: os.path.join(PATH_OUT,r[ND],r[N]+'.jpg'),axis=1)
df[DO]=df.apply(lambda r: os.path.dirname(r[O]),axis=1)
df[D]=df[N].str.extract('_d0(.)').astype(int)
df
# Out:
#                                                     PATH  \
# 0      /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...
# 1      /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...
# 2      /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...
# 3      /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...
# 4      /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...
# ...                                                  ...
# 42475  /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...
# 42476  /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...
# 42477  /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...
# 42478  /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...
# 42479  /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...
#
#                                 NAME    NAME_DAY  \
# 0      flxout_d01_20171202_000000.nc  2017-12-06
# 1      flxout_d01_20171202_010000.nc  2017-12-06
# 2      flxout_d01_20171202_020000.nc  2017-12-06
# 3      flxout_d01_20171202_030000.nc  2017-12-06
# 4      flxout_d01_20171202_040000.nc  2017-12-06
# ...                              ...         ...
# 42475  flxout_d02_20180531_190000.nc  2018-05-31
# 42476  flxout_d02_20180531_200000.nc  2018-05-31
# 42477  flxout_d02_20180531_210000.nc  2018-05-31
# 42478  flxout_d02_20180531_220000.nc  2018-05-31
# 42479  flxout_d02_20180531_230000.nc  2018-05-31
#
#                                                      OUT  \
# 0      /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...
# 1      /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...
# 2      /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...
# 3      /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...
# 4      /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...
# ...                                                  ...
# 42475  /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...
# 42476  /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...
# 42477  /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...
# 42478  /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...
# 42479  /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...
#
#                                                  DIR_OUT  DOM
# 0      /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...    1
# 1      /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...    1
# 2      /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...    1
# 3      /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...    1
# 4      /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...    1
# ...                                                  ...  ...
# 42475  /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...    2
# 42476  /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...    2
# 42477  /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...    2
# 42478  /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...    2
# 42479  /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpa...    2
#
# [42480 rows x 6 columns]

# %%
_dn = df[ND]
_dn = _dn.drop_duplicates()
_dd = df[D]
_dd = _dd.drop_duplicates()

# %%
for dom in _dd:
    for day in _dn:
        dfs = df[(df[ND]==day)&(df[D]==dom)]
        out = dfs[DO].iloc[0]+'.jpg'
        print(out)
        ax = axsplot()
        try:
            ds =xr.open_mfdataset(dfs.iloc[:][P],concat_dim=co.TIME,combine='nested', preprocess=fa.convert_ds_time_format)
            ds.sum(fa.get_dims_complement(ds,co.TIME))[co.CONC].plot(ax=ax)
        except: pass
        ax.figure.savefig(out)
        plt.close(ax.figure)
# Out:
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-06.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-07.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-08.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-09.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-10.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-11.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-12.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-13.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-14.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-15.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-16.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-17.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-18.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-19.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-20.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-21.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-22.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-23.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-24.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-25.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-26.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-27.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-28.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-29.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-30.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2017-12-31.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-01.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-02.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-03.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-04.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-05.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-06.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-07.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-08.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-09.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-10.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-11.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-12.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-13.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-14.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-15.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-16.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-17.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-18.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-19.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-20.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-21.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-22.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-23.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-24.jpg
# /homeappl/home/aliagadi/wrk/DONOTREMOVE/flexpart_management_data/runs/run_2019-09-25_15-25-01_/check_plots/2018-01-25.jpg
