# %%
from useful_scit.imps2.defs import *

# %%
ds = xr.open_dataset('/Volumes/mbProD/flexpart_management_data/'
                     'flexpart_management/tmp_data/new_log_pol_ds_asl_v01.nc')

# %%
ds1 = ds.rename({
    'R_CENTER':'x',
    'TH_CENTER':'y',
    'XLAT':'lat',
    'XLONG':'lon',
    'ZMID': 'z',
    'releases':'release_time'
})

# %%
dy = dict(
  standard_name = "projection_y_coordinate",
  long_name = "y-coordinate in projected coordinate system",
  units = "km",
  axis = "Y"
)

dx = dict(
  standard_name = "projection_x_coordinate",
  long_name = "x-coordinate in projected coordinate system",
  units = "km",
  axis = "X"
)

dlo = dict(
  standard_name = "longitude",
  long_name = "longitude",
  units = "degrees_east",
)

dla = dict(
  standard_name = "latitude",
  long_name = "latitude",
  units = "degrees_north",
)

dz = dict(
  axis = "Z",
  standard_name = "altitude",
  positive = "up",
  units = "m",
)

dt = dict(
#   units = "hours since 2021-02-18 00:00",
  standard_name = "time",
  long_name = "time",
  axis = "T",
)


atrs = dict(
    y   = dy,
    x   = dx,
    lon = dlo,
    lat = dla,
    z   = dz,
    release_time = dt
)

# %%
for l,v in atrs.items():
    ds1[l] = ds1[l].assign_attrs(v)

# %%
ds2 = ds1.transpose('release_time','z','y','x')
ds2 = ds2[{'release_time':[1000,1001]}]

# %%
ds2['z'].attrs={'units': 'hPa',
 'axis': 'Z',
 'standard_name': 'air_pressure',
 'positive': 'down'}

# %%
ds3 = ds2.reset_coords(drop=True)[['CONC']]

# %%
ds3['CONC'].coords
# Out:
# Coordinates:
#   * x             (x) float64 0.08046 0.09633 0.1153 ... 10.38 12.43 14.88
#   * y             (y) float64 0.08727 0.2618 0.4363 0.6109 ... 5.847 6.021 6.196
#   * release_time  (release_time) datetime64[ns] 2018-01-16T16:00:00 2018-01-1...
#   * z             (z) float64 250.0 750.0 1.25e+03 ... 1.425e+04 1.475e+04

# %%
ds3.load()
# Out:
# <xarray.Dataset>
# Dimensions:       (release_time: 2, x: 30, y: 36, z: 30)
# Coordinates:
#   * x             (x) float64 0.08046 0.09633 0.1153 ... 10.38 12.43 14.88
#   * y             (y) float64 0.08727 0.2618 0.4363 0.6109 ... 5.847 6.021 6.196
#   * release_time  (release_time) datetime64[ns] 2018-01-16T16:00:00 2018-01-1...
#   * z             (z) float64 250.0 750.0 1.25e+03 ... 1.425e+04 1.475e+04
# Data variables:
#     CONC          (release_time, z, y, x) float64 nan nan nan ... 0.0 0.0 0.0

# %%
ds2['TOPOGRAPHY']
# Out:
# <xarray.DataArray 'TOPOGRAPHY' (y: 36, x: 30)>
# array([[4666.36882286, 4584.26624665, 4486.43224855, ...,  118.42723083,
#           88.36790466,   69.7086792 ],
#        [4731.8935142 , 4729.61255629, 4740.43170587, ...,   89.9929657 ,
#           75.18263245,   56.9708519 ],
#        [4790.56916783, 4826.05782525, 4759.35941034, ...,   74.16873169,
#           54.55237961,   48.20749283],
#        ...,
#        [5195.10511058, 5123.67040271, 4952.52929214, ...,  197.31855774,
#          135.10871887,  161.49320984],
#        [5317.9287181 , 5251.80310885, 4802.42699499, ...,  169.12190247,
#          119.4114151 ,  140.29467773],
#        [5047.25225008, 5005.27527379, 4679.70712822, ...,  149.03707886,
#          110.85092926,  109.6342392 ]])
# Coordinates:
#   * x           (x) float64 0.08046 0.09633 0.1153 0.1381 ... 10.38 12.43 14.88
#   * y           (y) float64 0.08727 0.2618 0.4363 0.6109 ... 5.847 6.021 6.196
#     NUM         (x) int64 73 79 45 68 102 40 57 ... 80 117 165 240 342 494 652
#     TOPOGRAPHY  (y, x) float64 4.666e+03 4.584e+03 4.486e+03 ... 110.9 109.6
#     lat         (y, x) float64 -16.28 -16.27 -16.26 ... -5.955 -3.904 -1.516
#     GRIDAREA    (y, x) float64 2.566e+06 2.31e+06 ... 5.916e+10 8.031e+10
#     G_AREA      (y, x) float64 0.0002161 0.0001942 0.0004537 ... 3.311 4.798 6.5
#     lon         (y, x) float64 -68.12 -68.12 -68.12 ... -69.06 -69.24 -69.48
#     LAT_00      (y, x) float64 -16.28 -16.26 -16.25 ... -7.007 -5.164 -2.958
#     LON_00      (y, x) float64 -68.13 -68.13 -68.13 ... -69.78 -70.1 -70.49
#     LAT_10      (y, x) float64 -16.26 -16.25 -16.22 ... -5.164 -2.958 -0.3168
#     LON_10      (y, x) float64 -68.13 -68.13 -68.13 ... -70.1 -70.49 -70.96
#     LAT_11      (y, x) float64 -16.26 -16.25 -16.23 ... -4.992 -2.751 -0.06941
#     LON_11      (y, x) float64 -68.12 -68.11 -68.11 ... -68.13 -68.13 -68.13
#     LAT_01      (y, x) float64 -16.28 -16.26 -16.25 ... -6.863 -4.992 -2.751
#     LON_01      (y, x) float64 -68.12 -68.12 -68.11 ... -68.13 -68.13 -68.13

# %%
ds3['topo']=xr.zeros_like(ds2['TOPOGRAPHY'].reset_coords(drop=True)) + ds2['TOPOGRAPHY'].values

# %%
ds3['Temperature'] = xr.zeros_like(ds3['CONC'])+ds3['CONC'].values

# %%
ds3['Temperature']=ds3['Temperature'].where(~ds3['Temperature'].isnull(),0)

# %%
ds3['Temperature'].max()
# Out:
# <xarray.DataArray 'Temperature' ()>
# array(1930.51220703)

# %%
ds3['Temperature'].min()
# Out:
# <xarray.DataArray 'Temperature' ()>
# array(0.)

# %%
ds4 = ds3[['Temperature','topo']]

# %%
ds4['topo']
# Out:
# <xarray.DataArray 'topo' (y: 36, x: 30)>
# array([[4666.36882286, 4584.26624665, 4486.43224855, ...,  118.42723083,
#           88.36790466,   69.7086792 ],
#        [4731.8935142 , 4729.61255629, 4740.43170587, ...,   89.9929657 ,
#           75.18263245,   56.9708519 ],
#        [4790.56916783, 4826.05782525, 4759.35941034, ...,   74.16873169,
#           54.55237961,   48.20749283],
#        ...,
#        [5195.10511058, 5123.67040271, 4952.52929214, ...,  197.31855774,
#          135.10871887,  161.49320984],
#        [5317.9287181 , 5251.80310885, 4802.42699499, ...,  169.12190247,
#          119.4114151 ,  140.29467773],
#        [5047.25225008, 5005.27527379, 4679.70712822, ...,  149.03707886,
#          110.85092926,  109.6342392 ]])
# Coordinates:
#   * x        (x) float64 0.08046 0.09633 0.1153 0.1381 ... 10.38 12.43 14.88
#   * y        (y) float64 0.08727 0.2618 0.4363 0.6109 ... 5.847 6.021 6.196
#     lat      (y, x) float64 -16.28 -16.27 -16.26 -16.24 ... -5.955 -3.904 -1.516
#     lon      (y, x) float64 -68.12 -68.12 -68.12 -68.12 ... -69.06 -69.24 -69.48

# %%
ds4 = ds4.assign_coords({'lat':ds2['lat'].reset_coords(drop=True)})
ds4 = ds4.assign_coords({'lon':ds2['lon'].reset_coords(drop=True)})

# %%
ds4.to_netcdf('test12.nc',format='NETCDF3_CLASSIC')

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-132-31c4f4ce9503> in <module>
# ----> 1 d[4]
#
# ~/miniconda3/envs/b36/lib/python3.8/site-packages/xarray/core/dataarray.py in __getitem__(self, key)
#     640         else:
#     641             # xarray-style array indexing
# --> 642             return self.isel(indexers=self._item_key_to_dict(key))
#     643
#     644     def __setitem__(self, key: Any, value: Any) -> None:
#
# ~/miniconda3/envs/b36/lib/python3.8/site-packages/xarray/core/dataarray.py in isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    1045         # lists, or zero or one-dimensional np.ndarray's
#    1046
# -> 1047         variable = self._variable.isel(indexers, missing_dims=missing_dims)
#    1048
#    1049         coords = {}
#
# ~/miniconda3/envs/b36/lib/python3.8/site-packages/xarray/core/variable.py in isel(self, indexers, missing_dims, **indexers_kwargs)
#    1116
#    1117         key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1118         return self[key]
#    1119
#    1120     def squeeze(self, dim=None):
#
# ~/miniconda3/envs/b36/lib/python3.8/site-packages/xarray/core/variable.py in __getitem__(self, key)
#     765         """
#     766         dims, indexer, new_order = self._broadcast_indexes(key)
# --> 767         data = as_indexable(self._data)[indexer]
#     768         if new_order:
#     769             data = duck_array_ops.moveaxis(data, range(len(new_order)), new_order)
#
# ~/miniconda3/envs/b36/lib/python3.8/site-packages/xarray/core/indexing.py in __getitem__(self, key)
#    1292     def __getitem__(self, key):
#    1293         array, key = self._indexing_array_and_key(key)
# -> 1294         return array[key]
#    1295
#    1296     def __setitem__(self, key, value):
#
# IndexError: index 4 is out of bounds for axis 0 with size 2

# %%
ds3.to_netcdf('test6.nc')

# %%
ds2.load()
# Out:
# <xarray.Dataset>
# Dimensions:       (release_time: 2, x: 30, y: 36, z: 30)
# Coordinates:
#   * x             (x) float64 0.08046 0.09633 0.1153 ... 10.38 12.43 14.88
#   * y             (y) float64 0.08727 0.2618 0.4363 0.6109 ... 5.847 6.021 6.196
#     NUM           (x) int64 73 79 45 68 102 40 57 ... 80 117 165 240 342 494 652
#     TOPOGRAPHY    (y, x) float64 4.666e+03 4.584e+03 4.486e+03 ... 110.9 109.6
#     lat           (y, x) float64 -16.28 -16.27 -16.26 ... -5.955 -3.904 -1.516
#     GRIDAREA      (y, x) float64 2.566e+06 2.31e+06 ... 5.916e+10 8.031e+10
#     G_AREA        (y, x) float64 0.0002161 0.0001942 0.0004537 ... 4.798 6.5
#     lon           (y, x) float64 -68.12 -68.12 -68.12 ... -69.06 -69.24 -69.48
#   * release_time  (release_time) datetime64[ns] 2018-01-16T16:00:00 2018-01-1...
#     LAT_00        (y, x) float64 -16.28 -16.26 -16.25 ... -7.007 -5.164 -2.958
#     LON_00        (y, x) float64 -68.13 -68.13 -68.13 ... -69.78 -70.1 -70.49
#     LAT_10        (y, x) float64 -16.26 -16.25 -16.22 ... -5.164 -2.958 -0.3168
#     LON_10        (y, x) float64 -68.13 -68.13 -68.13 ... -70.1 -70.49 -70.96
#     LAT_11        (y, x) float64 -16.26 -16.25 -16.23 ... -4.992 -2.751 -0.06941
#     LON_11        (y, x) float64 -68.12 -68.11 -68.11 ... -68.13 -68.13 -68.13
#     LAT_01        (y, x) float64 -16.28 -16.26 -16.25 ... -6.863 -4.992 -2.751
#     LON_01        (y, x) float64 -68.12 -68.12 -68.11 ... -68.13 -68.13 -68.13
#   * z             (z) float64 250.0 750.0 1.25e+03 ... 1.425e+04 1.475e+04
# Data variables:
#     CONC          (release_time, z, y, x) float64 nan nan nan ... 0.0 0.0 0.0
#     AGE           (release_time, z, y, x) float64 nan nan nan ... nan nan nan

# %%
ds2['CONC'].attrs
# Out:
# {}

# %%
ds2.to_netcdf('test_del1.nc')

# %%
ff = '/Volumes/Transcend/scratch/forecast_model.nc'

dm = xr.open_dataset(ff)
dm.attrs={}
dm = dm.drop('lambert_projection')

# %%
dm['Temperature'].attrs={}

# %%
dm['pressure'].attrs
# Out:
# {'units': 'hPa',
#  'axis': 'Z',
#  'standard_name': 'air_pressure',
#  'positive': 'down'}

# %%
dm.to_netcdf('ex3.nc')

# %%
dm['Temperature'].attrs
# Out:
# {}

# %%
dm.reset_coords()
# Out:
# <xarray.Dataset>
# Dimensions:        (forecast_time: 13, pressure: 7, x: 101, y: 67)
# Coordinates:
#   * x              (x) float32 -150.0 -147.0 -144.0 -141.0 ... 144.0 147.0 150.0
#   * y              (y) float32 -100.0 -97.0 -94.0 -91.0 ... 89.0 92.0 95.0 98.0
#   * pressure       (pressure) float32 1000.0 925.0 850.0 700.0 500.0 300.0 250.0
#   * forecast_time  (forecast_time) datetime64[ns] 2021-02-18T22:00:00 ... 202...
# Data variables:
#     Temperature    (forecast_time, pressure, y, x) float32 -0.9859797 ... 0.3...
#     lon            (y, x) float64 -106.6 -106.6 -106.5 ... -103.5 -103.4 -103.4
#     lat            (y, x) float64 39.18 39.18 39.18 39.18 ... 40.79 40.79 40.79
