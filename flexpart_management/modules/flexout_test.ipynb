# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import flexpart_management.modules.FLEXOUT as FO
import flexpart_management.modules.flx_array as fa

# %%
fo_dic  = dict(
dom = 'd01',
folder_path = '/Volumes/mbProD/Downloads/flex_out/run_2019-06-02_20-42-05_/2017-12-10',
folder_path_out = '/Volumes/mbProD/Downloads/flex_out/log_pol',
run_name= 'run_2019-06-02_20-42-05_',
)

# %%
fo = FO.FLEXOUT(**fo_dic)
# Out:
# /Volumes/mbProD/Downloads/flex_out/run_2019-06-02_20-42-05_/2017-12-10/*header_*d01*
# /Volumes/mbProD/Downloads/flex_out/run_2019-06-02_20-42-05_/2017-12-10/header_d01.nc
# /Volumes/mbProD/Downloads/flex_out/run_2019-06-02_20-42-05_/2017-12-10/*flxout_*d01*
# ['/Volumes/mbProD/Downloads/flex_out/run_2019-06-02_20-42-05_/2017-12-10/flxout_d01_20171206_000000.nc']

# %%
rels = fo.flexout_hour_ds[fa.RL].to_dataframe()

# %%
rdf = fo.export_log_polar_coords()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-193-6e2ada3c9d2b> in <module>
# ----> 1 rdf = fo.export_log_polar_coords()
#
# ~/flexpart_management/flexpart_management/modules/FLEXOUT.py in export_log_polar_coords(self)
#     127             lambda n: os.path.join(out_path,n))
#     128         for k,r in rel_df.iterrows():
# --> 129             lp_ds = self.get_log_polar_coords(r[co.RL])
#     130             fa.compressed_netcdf_save(lp_ds,r[rp])
#     131
#
# ~/flexpart_management/flexpart_management/modules/FLEXOUT.py in get_log_polar_coords(self, release, coords_to_keep, rounding_vals)
#     112                 sum_ds[v],
#     113                 *val,
# --> 114                 dim2keep=keep_list)
#     115
#     116         return lp_ds
#
# ~/flexpart_management/flexpart_management/modules/flx_array.py in data_array_to_logpolar(da, r_round_log, th_round_rad, lat_center, lon_center, dim2keep)
#     380     name = da.name
#     381
# --> 382     df = nda.to_dataframe().reset_index()
#     383     df = df[[R_CENTER, TH_CENTER, name,*dim2keep]]
#     384     df: pd.DataFrame = df.groupby([R_CENTER, TH_CENTER,*dim2keep]).sum()
#
# ~/miniconda3/envs/b36/lib/python3.6/site-packages/xarray/core/dataarray.py in to_dataframe(self, name)
#    1687         unique_name = '__unique_name_identifier_z98xfz98xugfg73ho__'
#    1688         ds = self._to_dataset_whole(name=unique_name)
# -> 1689         df = ds._to_dataframe(dims)
#    1690         df.columns = [name if c == unique_name else c
#    1691                       for c in df.columns]
#
# ~/miniconda3/envs/b36/lib/python3.6/site-packages/xarray/core/dataset.py in _to_dataframe(self, ordered_dims)
#    3324         columns = [k for k in self.variables if k not in self.dims]
#    3325         data = [self._variables[k].set_dims(ordered_dims).values.reshape(-1)
# -> 3326                 for k in columns]
#    3327         index = self.coords.to_index(ordered_dims)
#    3328         return pd.DataFrame(OrderedDict(zip(columns, data)), index=index)
#
# ~/miniconda3/envs/b36/lib/python3.6/site-packages/xarray/core/dataset.py in <listcomp>(.0)
#    3324         columns = [k for k in self.variables if k not in self.dims]
#    3325         data = [self._variables[k].set_dims(ordered_dims).values.reshape(-1)
# -> 3326                 for k in columns]
#    3327         index = self.coords.to_index(ordered_dims)
#    3328         return pd.DataFrame(OrderedDict(zip(columns, data)), index=index)
#
# ~/miniconda3/envs/b36/lib/python3.6/site-packages/xarray/core/variable.py in values(self)
#     390     def values(self):
#     391         """The variable's data as a numpy.ndarray"""
# --> 392         return _as_array_or_item(self._data)
#     393
#     394     @values.setter
#
# ~/miniconda3/envs/b36/lib/python3.6/site-packages/xarray/core/variable.py in _as_array_or_item(data)
#     211     TODO: remove this (replace with np.asarray) once these issues are fixed
#     212     """
# --> 213     data = np.asarray(data)
#     214     if data.ndim == 0:
#     215         if data.dtype.kind == 'M':
#
# ~/miniconda3/envs/b36/lib/python3.6/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ~/miniconda3/envs/b36/lib/python3.6/site-packages/dask/array/core.py in __array__(self, dtype, **kwargs)
#    1045
#    1046     def __array__(self, dtype=None, **kwargs):
# -> 1047         x = self.compute()
#    1048         if dtype and x.dtype != dtype:
#    1049             x = x.astype(dtype)
#
# ~/miniconda3/envs/b36/lib/python3.6/site-packages/dask/base.py in compute(self, **kwargs)
#     154         dask.base.compute
#     155         """
# --> 156         (result,) = compute(self, traverse=False, **kwargs)
#     157         return result
#     158
#
# ~/miniconda3/envs/b36/lib/python3.6/site-packages/dask/base.py in compute(*args, **kwargs)
#     396     keys = [x.__dask_keys__() for x in collections]
#     397     postcomputes = [x.__dask_postcompute__() for x in collections]
# --> 398     results = schedule(dsk, keys, **kwargs)
#     399     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     400
#
# ~/miniconda3/envs/b36/lib/python3.6/site-packages/dask/threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      74     results = get_async(pool.apply_async, len(pool._pool), dsk, result,
#      75                         cache=cache, get_id=_thread_get_id,
# ---> 76                         pack_exception=pack_exception, **kwargs)
#      77
#      78     # Cleanup pools associated to dead threads
#
# ~/miniconda3/envs/b36/lib/python3.6/site-packages/dask/local.py in get_async(apply_async, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, **kwargs)
#     451             # Main loop, wait on tasks to finish, insert new ones
#     452             while state['waiting'] or state['ready'] or state['running']:
# --> 453                 key, res_info, failed = queue_get(queue)
#     454                 if failed:
#     455                     exc, tb = loads(res_info)
#
# ~/miniconda3/envs/b36/lib/python3.6/site-packages/dask/local.py in queue_get(q)
#     139 else:
#     140     def queue_get(q):
# --> 141         return q.get()
#     142
#     143
#
# ~/miniconda3/envs/b36/lib/python3.6/queue.py in get(self, block, timeout)
#     162             elif timeout is None:
#     163                 while not self._qsize():
# --> 164                     self.not_empty.wait()
#     165             elif timeout < 0:
#     166                 raise ValueError("'timeout' must be a non-negative number")
#
# ~/miniconda3/envs/b36/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
for k,r in rdf.iterrows():
    v  = r

# %%
v[fa.RL]
# Out:
# Timestamp('2017-12-10 23:00:00')

# %%
rels.dt.strftime('%Y')
# Out:
# releases
# 2017-12-10 00:00:00    2017
# 2017-12-10 01:00:00    2017
# 2017-12-10 02:00:00    2017
# 2017-12-10 03:00:00    2017
# 2017-12-10 04:00:00    2017
# 2017-12-10 05:00:00    2017
# 2017-12-10 06:00:00    2017
# 2017-12-10 07:00:00    2017
# 2017-12-10 08:00:00    2017
# 2017-12-10 09:00:00    2017
# 2017-12-10 10:00:00    2017
# 2017-12-10 11:00:00    2017
# 2017-12-10 12:00:00    2017
# 2017-12-10 13:00:00    2017
# 2017-12-10 14:00:00    2017
# 2017-12-10 15:00:00    2017
# 2017-12-10 16:00:00    2017
# 2017-12-10 17:00:00    2017
# 2017-12-10 18:00:00    2017
# 2017-12-10 19:00:00    2017
# 2017-12-10 20:00:00    2017
# 2017-12-10 21:00:00    2017
# 2017-12-10 22:00:00    2017
# 2017-12-10 23:00:00    2017
# Name: releases, dtype: object

# %%
r0 = rels[0].to_series()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-156-35f8acdde404> in <module>
# ----> 1 r0 = rels[0].to_series()
#
# ~/miniconda3/envs/b36/lib/python3.6/site-packages/xarray/core/dataarray.py in to_series(self)
#    1698         (in the form of a :py:class:`pandas.MultiIndex`).
#    1699         """
# -> 1700         index = self.coords.to_index()
#    1701         return pd.Series(self.values.reshape(-1), index=index, name=self.name)
#    1702
#
# ~/miniconda3/envs/b36/lib/python3.6/site-packages/xarray/core/coordinates.py in to_index(self, ordered_dims)
#      76
#      77         if len(ordered_dims) == 0:
# ---> 78             raise ValueError('no valid index for a 0-dimensional object')
#      79         elif len(ordered_dims) == 1:
#      80             (dim,) = ordered_dims
#
# ValueError: no valid index for a 0-dimensional object

# %%
r0.dt.str
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-155-e2ef20bd47a2> in <module>
# ----> 1 r0.dt.str
#
# AttributeError: 'DatetimeAccessor' object has no attribute 'str'

# %%
res = fo.get_log_polar_coords(rels[1])

# %%
fa.compressed_netcdf_save(res,'/tmp/borrar.nc')

# %%
res.sum()/96
# Out:
# <xarray.DataArray 'CONC' ()>
# array(3575.528971)

# %%
ax = fa.get_ax_bolivia()
fa.logpolar_plot(res,ax=ax)
